# %%
import torch
import importlib
from example_algos.util.nifti_io import ni_save, ni_load
import matplotlib.pyplot as plt
import numpy as np

# %%
import example_algos.util.function as F

# %%
importlib.reload(F)
# Out:
# <module 'example_algos.util.function' from '/home/cxr/vscode/mood/example_algos/util/function.py'>

# %%
save_path = '/home/cxr/Downloads/a'

# %%
path = '/home/cxr/Program_Datas/mood/validate/data/c4_00020_0_1.nii.gz'

# %%
np_array, np_aff = ni_load(path)

# %%
import cv2

# %%
img = np_array[128]

# %%
temp = img * 256
temp = temp.astype(np.uint8)
temp = cv2.Canny(temp, 150, 200)
img = temp.astype(np.float) / 256

# %%
plt.imshow(img, cmap='gray')

# %%
np.where(img!=1)[0]
# Out:
# array([  0,   0,   0, ..., 255, 255, 255])

# %%
temp = img * 256
temp = temp.astype(np.uint8)
temp = cv2.Canny(temp, 150, 200)

# %%
temp = img * 256

# %%
temp = temp.astype(np.uint8)

# %%
temp = cv2.Canny(temp, 150, 200)

# %%
temp.shape
# Out:
# (256, 256)
