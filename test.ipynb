# %%
import importlib
from example_algos.util.nifti_io import ni_save, ni_load
import matplotlib.pyplot as plt

# %%
import example_algos.util.function as F

# %%
importlib.reload(F)
# Out:
# <module 'example_algos.util.function' from '/home/cxr/vscode/mood/example_algos/util/function.py'>

# %%
path='/home/cxr/Program_Datas/mood/validate_c/eval/unet_predict/predict/pixel/score/c4_00020_0_1.nii.gz'

# %%
path = '/home/cxr/Program_Datas/mood/validate_c/label/pixel/c4_00100_1_5.nii.gz'

# %%
np_array, np_aff = ni_load(path)

# %%
n, bins, patches = plt.hist(np_array.flatten(), bins=50, log=True)
plt.savefig('/home/cxr/aaa')
